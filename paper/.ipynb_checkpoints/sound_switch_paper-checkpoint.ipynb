# %% [markdown]
# # Sound Switch

# %% [markdown]
# # TODOs
# - Include musical background in analyses; start with dichotomized variable, move on to continuous.
# - Make visual analogue of this task. White square, black square, 500 ms each for 10 s.

# %% [markdown]
# # Imports

# %%
# %reset -f
# %matplotlib inline
# %config InlineBackend.figure_format = "retina" # High-res graphs (rendered irrelevant by svg option below)
# %config InlineBackend.print_figure_kwargs = {"bbox_inches": "tight"} # No extra white space
# %config InlineBackend.figure_format = "svg" # 'png' is default
 
import warnings
warnings.filterwarnings("ignore") # Because we are adults
from IPython.core.debugger import set_trace
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scipy
import seaborn as sns
from dfply import *

# iPyPublish imports
# from ipypublish.scripts.ipynb_latex_setup import *
# from IPython.display import SVG, display, Markdown

# %% [markdown]
# # Experiment 1

# %% [markdown]
# ## Methods

# %% [markdown]
# ### Stimuli
# - Two types of sound stimuli: tones and guitar chords
#     - Beeps alternate between pure C4 tone (261.626 Hz) and pure G tone (391.995 Hz)
#     - Guitar chords alternate between a C chord and a G chord strummed on guitar, taken from [here](https://www.apronus.com/music/onlineguitar.htm), which were subsequently recorded and amplified (25.98 db and 25.065 db respectively) using Audacity version 2.3.0 (using Effect --> Amplify) via Windows 10's Stereo Mix drivers.
# - 20 sounds per stimulus
# - Crossfade of 50 ms between sounds
# - Each stimulus was 10,000 milliseconds long, with an additional 150 ms of silence at the start of the recording.
# - 9 switch rates between 0.1 and 0.9
# - 10 stimuli for each switch rate, for a total of 180 stimuli, all presented as a single block. 30 frame ITI.
# - 20 repeated stimuli chosen via the same random choice for each subject (presentation order was via a unique random choice for each subject, however).
# - One practice beep stimulus at 0.5 switch rate presented at the start of the experiment.

# %% [markdown]
# ## Results

# %% [markdown]
# ### Read in data

# %%
import glob, os

separator = r"\t"
data_dir = "../data/2019-03-14"
prefix = "Sound Switch"
extension = ".txt"
search = f"{data_dir}/{prefix}*{extension}"

# Get each subject's data and concatenate into 
# one larger DataFrame
all_data = pd.DataFrame()
for file_name in glob.glob(search):
    subject_data = pd.read_csv(file_name, sep=separator)
    if all_data.shape == (0, 0):
        all_data = subject_data
    else: 
        all_data = all_data.append(subject_data)

all_data.reset_index(inplace=True, drop=True)
all_data.head()
# Out:
#    Subject ID  Condition  Block #  Trial #  Switch Rate  Exemplar  \
# 0           1  patterned        1        1          0.3        10
# 1           1  patterned        1        2          0.1        17
# 2           1  patterned        1        3          0.1        18
# 3           1  patterned        1        4          0.7        10
# 4           1  patterned        1        5          0.9         9
#
#                                            File Name Rating     RT  \
# 0  ../stimuli/combined/switch-0.3_chunk-500_C_G_a...     41  7.309
# 1  ../stimuli/combined/switch-0.1_chunk-500_C_G_a...    100  2.725
# 2  ../stimuli/combined/switch-0.1_chunk-500_C_G_a...     71  3.493
# 3  ../stimuli/combined/switch-0.7_chunk-500_C_G_a...     68  2.446
# 4  ../stimuli/combined/switch-0.9_chunk-500_C_G_a...    100  2.178
#
#                               Rating History  Trial Duration  Block Duration  \
# 0     [(None, 0.0), (41, 6.48), (41, 7.309)]       18.222353       18.223059
# 1  [(None, 0.0), (100, 1.817), (100, 2.725)]       13.631996       31.859845
# 2    [(None, 0.0), (71, 2.784), (71, 3.493)]       14.413484       46.279105
# 3    [(None, 0.0), (68, 1.726), (68, 2.446)]       13.391476       59.676363
# 4  [(None, 0.0), (100, 1.333), (100, 2.178)]       13.100105       72.781313
#
#    Session Duration  Experiment Duration        Start Date  \
# 0       3670.838750            19.814849  2019_Feb_14_1305
# 1       3684.475536            33.451635  2019_Feb_14_1305
# 2       3698.894796            47.870896  2019_Feb_14_1305
# 3       3712.292055            61.268155  2019_Feb_14_1305
# 4       3725.397003            74.373104  2019_Feb_14_1305
#
#                 Experiment Testing Location Experimenter Initials  \
# 0  Sound Switch 12-20-2018       318-laptop                   bpl
# 1  Sound Switch 12-20-2018       318-laptop                   bpl
# 2  Sound Switch 12-20-2018       318-laptop                   bpl
# 3  Sound Switch 12-20-2018       318-laptop                   bpl
# 4  Sound Switch 12-20-2018       318-laptop                   bpl
#
#   Subject Initials
# 0              WPH
# 1              WPH
# 2              WPH
# 3              WPH
# 4              WPH

# %% [markdown]
# ### Demographics
# Race demographics are borked for the moment; will fix later.

# %%
# Load data
debriefing_file_name = f"{data_dir}/sound_switch_debriefing.xlsx"
debriefing_data = pd.read_excel(debriefing_file_name)

# %%
# Get NA subjects
na_subjects_index = debriefing_data[debriefing_data["Initials"].isna()].index
print(f"NA subjects: {na_subjects_index}")
# Remove NA subjects
debriefing_data.drop(index=na_subjects_index, axis=0, inplace=True)

debriefing_data.iloc[30:36]
# Out:
# NA subjects: Int64Index([], dtype='int64')
#     Sub # Initials       Date     Time  \
# 30     31      ADP 2019-02-27   2:00PM
# 31     32      NID 2019-02-28   9:15AM
# 32     33       EG 2019-02-28  10:45AM
# 33     34      MTA 2019-02-28   2:00PM
# 34     35      CPC 2019-02-28   3:45PM
# 35     36      KSM 2019-03-01   9:45AM
#
#                                                  Race  Age Gender Credit/Pay  \
# 30                                            []Asian   18      F     CR1.00
# 31  [Middle Eastern/Arab American;Latino/Hispanic ...   20      M     CR1.00
# 32                        [Latino/Hispanic American;]   18      F     CR1.00
# 33                                            []White   22      F     CR1.00
# 34                                            []White   22      F     CR1.00
# 35  [Black/African American;White/European American;]   19      F     CR1.00
#
#     Volume                What did you think we were testing?  ...  \
# 30     0.5  Sound patterns. To see if would get up and lea...  ...
# 31     0.5  "You said patterns. The computer said attentio...  ...
# 32     0.5  Whether people could recognize patterns in the...  ...
# 33     0.5  Looked at how modulation of sounds affected ho...  ...
# 34     0.5  Patterns. Repetition of patterns. Attention pe...  ...
# 35     0.5  Not really sure. P guesses if you go from tone...  ...
#
#    Did you notice anything interesting during the experiment that you wanted to share?  \
# 30  No. Although P was pretty happy when P saw the...
# 31                                    No. Not really.
# 32                                               No.
# 33                     No. Not really. Nothing crazy.
# 34        Thought that it was fun. Really enjoyed it.
# 35                                                No.
#
#    Did you think that some the sequences sounded more patterned than others? If so, what about them made them sound more patterned to you?  \
# 30  Yeah. Some of them were all the same or altern...
# 31  Yes. There were some that mirrored themselves ...
# 32  Yeah. Some had more variations than others. (t...
# 33  Of the two instruments, the one that was not a...
# 34  Yes. Some had more repetition of the same seri...
# 35  Yeah. If it was 4 low notes, 4 high notes, 4 l...
#
#    Did you think that some the sequences sounded more beautiful than others? If so, what about them made them sound more beautiful to you?  \
# 30  Yeah, The guitar-sounding ones was much better...
# 31  Generally, they sounded better in the beginnin...
# 32   Kind of liked the guitar ones a little bit more.
# 33  Yes. P guesses that some that were more rhythm...
# 34  Yes. Liked one of the instruments more than th...
# 35  Yeah. Whatever ones sounded more patterned in ...
#
#    Did you think there was a relationship between how beautiful the sequence sounded and how patterned it sounded? If so, what is that relationship?  \
# 30                                No. Don't think so.
# 31  Yeah. Depends on what is meant by "patterned"....
# 32  If it was more beautiful, then would consider ...
# 33  Yes. Felt that ones that were more patterned w...
# 34  Yes. Felt that the pattenrs carried more of a ...
# 35  Yeah. Would say so. The more patterned it was,...
#
#    Did you find certain types of trials harder than others?  \
# 30  Felt that ones that felt like they were more r...
# 31             There really wasn't one kind of trial.
# 32  Some times they sounded the same, so P could n...
# 33                                  No. Not over all.
# 34  Yes. It was harder to focus at the end. Though...
# 35                                                No.
#
#           Is there anything else you'd like to share?  \
# 30                                                No.
# 31                                               No.
# 32                                                No.
# 33                                    No. Not really.
# 34                                  I don't think so.
# 35  Thinks that we should let people know how to a...
#
#    Any Musical Background or Experience?  \
# 30                                   Yes
# 31                                   Yes
# 32                                   Yes
# 33                                   Yes
# 34                                   Yes
# 35                                   Yes
#
#    Years of Musical Background or Experience  \
# 30                                    1 year
# 31                                  11 years
# 32                                   3 years
# 33                                  10 years
# 34                                   2 years
# 35                                   7 years
#
#                                Music Background Notes Notes
# 30         Played piano for 1 year, when 6 years old.   NaN
# 31   Self-identifies as a musician. Started playin...   NaN
# 32   Not really. Was in band in middle school (5th...   NaN
# 33   Kind of plays the guitar (2 years), playeds t...   NaN
# 34   played saxophone (alto?) in middle school (2 ...   NaN
# 35   Sings in the chapel choir here. (been singing...   NaN
#
# [6 rows x 24 columns]

# %% [markdown]
# #### Gender

# %%
debriefing_data["Gender"].value_counts()
# Out:
# F    31
# M    18
# Name: Gender, dtype: int64

# %% [markdown]
# #### Age

# %%
debriefing_data["Age"].describe().round(2)
# Out:
# count    49.00
# mean     19.73
# std       1.24
# min      18.00
# 25%      19.00
# 50%      19.00
# 75%      21.00
# max      22.00
# Name: Age, dtype: float64

# %% [markdown]
# ### Preprocessing

# %% [markdown]
# #### Determine stimulus type

# %%
def get_stimulus_type(row):
    """
    All stimuli under 10 are guitar; the rest are tones.
    """
    return "guitar" if row["Exemplar"] < 10 else "tone"

all_data["Stimulus Type"] = all_data.apply(get_stimulus_type, axis=1)
all_data.head()
# Out:
#    Subject ID  Condition  Block #  Trial #  Switch Rate  Exemplar  \
# 0           1  patterned        1        1          0.3        10
# 1           1  patterned        1        2          0.1        17
# 2           1  patterned        1        3          0.1        18
# 3           1  patterned        1        4          0.7        10
# 4           1  patterned        1        5          0.9         9
#
#                                            File Name Rating     RT  \
# 0  ../stimuli/combined/switch-0.3_chunk-500_C_G_a...     41  7.309
# 1  ../stimuli/combined/switch-0.1_chunk-500_C_G_a...    100  2.725
# 2  ../stimuli/combined/switch-0.1_chunk-500_C_G_a...     71  3.493
# 3  ../stimuli/combined/switch-0.7_chunk-500_C_G_a...     68  2.446
# 4  ../stimuli/combined/switch-0.9_chunk-500_C_G_a...    100  2.178
#
#                               Rating History  Trial Duration  Block Duration  \
# 0     [(None, 0.0), (41, 6.48), (41, 7.309)]       18.222353       18.223059
# 1  [(None, 0.0), (100, 1.817), (100, 2.725)]       13.631996       31.859845
# 2    [(None, 0.0), (71, 2.784), (71, 3.493)]       14.413484       46.279105
# 3    [(None, 0.0), (68, 1.726), (68, 2.446)]       13.391476       59.676363
# 4  [(None, 0.0), (100, 1.333), (100, 2.178)]       13.100105       72.781313
#
#    Session Duration  Experiment Duration        Start Date  \
# 0       3670.838750            19.814849  2019_Feb_14_1305
# 1       3684.475536            33.451635  2019_Feb_14_1305
# 2       3698.894796            47.870896  2019_Feb_14_1305
# 3       3712.292055            61.268155  2019_Feb_14_1305
# 4       3725.397003            74.373104  2019_Feb_14_1305
#
#                 Experiment Testing Location Experimenter Initials  \
# 0  Sound Switch 12-20-2018       318-laptop                   bpl
# 1  Sound Switch 12-20-2018       318-laptop                   bpl
# 2  Sound Switch 12-20-2018       318-laptop                   bpl
# 3  Sound Switch 12-20-2018       318-laptop                   bpl
# 4  Sound Switch 12-20-2018       318-laptop                   bpl
#
#   Subject Initials Stimulus Type
# 0              WPH          tone
# 1              WPH          tone
# 2              WPH          tone
# 3              WPH          tone
# 4              WPH        guitar

# %% [markdown]
# #### Determine if trial is a repeated stimulus

# %%
num_trials = 200
num_repeated_trials = 20 # at end of task
start_repeated_trial_index = num_trials - num_repeated_trials + 1

all_data["Repeat Trial"] = all_data["Trial #"] >= start_repeated_trial_index
all_data.head()
# Out:
#    Subject ID  Condition  Block #  Trial #  Switch Rate  Exemplar  \
# 0           1  patterned        1        1          0.3        10
# 1           1  patterned        1        2          0.1        17
# 2           1  patterned        1        3          0.1        18
# 3           1  patterned        1        4          0.7        10
# 4           1  patterned        1        5          0.9         9
#
#                                            File Name Rating     RT  \
# 0  ../stimuli/combined/switch-0.3_chunk-500_C_G_a...     41  7.309
# 1  ../stimuli/combined/switch-0.1_chunk-500_C_G_a...    100  2.725
# 2  ../stimuli/combined/switch-0.1_chunk-500_C_G_a...     71  3.493
# 3  ../stimuli/combined/switch-0.7_chunk-500_C_G_a...     68  2.446
# 4  ../stimuli/combined/switch-0.9_chunk-500_C_G_a...    100  2.178
#
#                               Rating History  ...  Block Duration  \
# 0     [(None, 0.0), (41, 6.48), (41, 7.309)]  ...       18.223059
# 1  [(None, 0.0), (100, 1.817), (100, 2.725)]  ...       31.859845
# 2    [(None, 0.0), (71, 2.784), (71, 3.493)]  ...       46.279105
# 3    [(None, 0.0), (68, 1.726), (68, 2.446)]  ...       59.676363
# 4  [(None, 0.0), (100, 1.333), (100, 2.178)]  ...       72.781313
#
#    Session Duration  Experiment Duration        Start Date  \
# 0       3670.838750            19.814849  2019_Feb_14_1305
# 1       3684.475536            33.451635  2019_Feb_14_1305
# 2       3698.894796            47.870896  2019_Feb_14_1305
# 3       3712.292055            61.268155  2019_Feb_14_1305
# 4       3725.397003            74.373104  2019_Feb_14_1305
#
#                 Experiment Testing Location Experimenter Initials  \
# 0  Sound Switch 12-20-2018       318-laptop                   bpl
# 1  Sound Switch 12-20-2018       318-laptop                   bpl
# 2  Sound Switch 12-20-2018       318-laptop                   bpl
# 3  Sound Switch 12-20-2018       318-laptop                   bpl
# 4  Sound Switch 12-20-2018       318-laptop                   bpl
#
#   Subject Initials Stimulus Type Repeat Trial
# 0              WPH          tone        False
# 1              WPH          tone        False
# 2              WPH          tone        False
# 3              WPH          tone        False
# 4              WPH        guitar        False
#
# [5 rows x 21 columns]

# %% [markdown]
# #### Remove subjects with "None" ratings

# %%
subjects_with_missing_data = all_data[all_data["Rating"] == "None"]["Subject ID"]
print(f"Bad subjects: \n {subjects_with_missing_data}")
all_data = all_data[~all_data["Subject ID"].isin(subjects_with_missing_data)]
# Out:
# Bad subjects:
#  6347    32
# Name: Subject ID, dtype: int64

# %% [markdown]
# #### Re-convert ratings to numeric

# %%
all_data["Rating"] = pd.to_numeric(all_data["Rating"])

# %% [markdown]
# #### Get subject reliability

# %%
subject_reliability_df = pd.DataFrame(
    index=[],
    columns=[
        "subject_id",
        "condition",        
        "correlation",
        "p-value",
        "fisher_z",
    ],
)
subject_ids = all_data["Subject ID"].unique()
for subject_id in subject_ids:
    subject_data = all_data >> mask(X["Subject ID"] == subject_id)
    subject_data.sort_values(by=["File Name"], inplace=True)
    repeated_stimuli = (
        subject_data 
        >> mask(X["Repeat Trial"] == True)
        >> select(["File Name"])
    )
    
    first_ratings_data = subject_data[
        (subject_data["File Name"].isin(repeated_stimuli["File Name"]))
        & (subject_data["Repeat Trial"] == False)
    ]["Rating"].tolist()
    
    second_ratings_data = subject_data[
        (subject_data["File Name"].isin(repeated_stimuli["File Name"]))
        & (subject_data["Repeat Trial"] == True)
    ]["Rating"].tolist()
    
    subject_reliability_corr = scipy.stats.pearsonr(
        first_ratings_data, second_ratings_data
    )
    
    # Needs to be in arrays for pandas
    # XXX break down by stimulus type?
    this_corr_row = {
        "subject_id": [subject_id],
        "condition": [subject_data["Condition"].iloc[0]],        
        "correlation": [subject_reliability_corr[0]],
        "p-value": [subject_reliability_corr[1]],
        "fisher_z": [np.arctanh(subject_reliability_corr[0])],
    }
    this_corr_row = pd.DataFrame.from_dict(this_corr_row)
    subject_reliability_df = subject_reliability_df.append(this_corr_row)
    
subject_reliability_df.round(3)
# Out:
#   subject_id  condition  correlation  p-value  fisher_z
# 0          1  patterned        0.105    0.660     0.105
# 0          2  beautiful        0.952    0.000     1.857
# 0          3  patterned        0.633    0.003     0.747
# 0          4  beautiful        0.207    0.382     0.210
# 0          5  patterned        0.795    0.000     1.086
# 0          6  beautiful       -0.176    0.457    -0.178
# 0          7  patterned        0.301    0.198     0.310
# 0          8  beautiful        0.938    0.000     1.719
# 0          9  patterned       -0.157    0.508    -0.159
# 0         10  beautiful        0.165    0.486     0.167
# 0         11  patterned        0.243    0.301     0.248
# 0         12  beautiful        0.912    0.000     1.538
# 0         13  patterned        0.598    0.005     0.690
# 0         14  beautiful       -0.070    0.770    -0.070
# 0         15  patterned        0.789    0.000     1.068
# 0         16  beautiful       -0.093    0.696    -0.093
# 0         17  patterned        0.036    0.881     0.036
# 0         18  beautiful        0.327    0.160     0.339
# 0         19  patterned        0.732    0.000     0.932
# 0         20  beautiful        0.052    0.829     0.052
# 0         21  patterned       -0.130    0.586    -0.130
# 0         22  beautiful        0.377    0.101     0.397
# 0         23  patterned        0.544    0.013     0.609
# 0         24  beautiful        0.791    0.000     1.075
# 0         25  patterned        0.425    0.062     0.453
# 0         26  beautiful        0.645    0.002     0.767
# 0         27  patterned        0.323    0.165     0.334
# 0         28  beautiful        0.339    0.144     0.353
# 0         29  patterned        0.370    0.108     0.389
# 0         30  beautiful        0.250    0.287     0.256
# 0         31  patterned        0.198    0.403     0.201
# 0         33  patterned        0.375    0.103     0.394
# 0         34  beautiful        0.317    0.173     0.329
# 0         35  patterned        0.420    0.065     0.447
# 0         36  beautiful        0.123    0.605     0.124
# 0         37  patterned        0.001    0.996     0.001
# 0         38  beautiful        0.313    0.178     0.324
# 0         39  patterned        0.616    0.004     0.719
# 0         40  beautiful        0.326    0.161     0.338
# 0         41  patterned        0.777    0.000     1.038
# 0         42  beautiful        0.230    0.330     0.234
# 0         43  patterned        0.063    0.792     0.063
# 0         44  beautiful        0.443    0.050     0.476
# 0         45  patterned        0.433    0.057     0.463
# 0         46  beautiful       -0.038    0.872    -0.038
# 0         47  patterned       -0.307    0.188    -0.318
# 0         48  beautiful        0.304    0.192     0.314
# 0         49  patterned        0.821    0.000     1.161

# %% [markdown]
# #### Remove unreliable subjects

# %%
# Keep subjects with positive correlation
subject_reliability_df = subject_reliability_df[subject_reliability_df["correlation"] >= 0]
# Keep subjects that have defined data
subject_reliability_df = subject_reliability_df.replace(
    [np.inf, -np.inf], np.nan
).dropna()
reliable_subjects = subject_reliability_df["subject_id"].unique()
no_repeat_data = all_data[(all_data["Subject ID"].isin(reliable_subjects)) & (all_data["Repeat Trial"]==False)]
print(f"Remaining participants: {subject_reliability_df.shape[0]}")
print(f"Data without repeat trials:")
no_repeat_data.head()
# Out:
# Remaining participants: 41
# Data without repeat trials:
#    Subject ID  Condition  Block #  Trial #  Switch Rate  Exemplar  \
# 0           1  patterned        1        1          0.3        10
# 1           1  patterned        1        2          0.1        17
# 2           1  patterned        1        3          0.1        18
# 3           1  patterned        1        4          0.7        10
# 4           1  patterned        1        5          0.9         9
#
#                                            File Name  Rating     RT  \
# 0  ../stimuli/combined/switch-0.3_chunk-500_C_G_a...      41  7.309
# 1  ../stimuli/combined/switch-0.1_chunk-500_C_G_a...     100  2.725
# 2  ../stimuli/combined/switch-0.1_chunk-500_C_G_a...      71  3.493
# 3  ../stimuli/combined/switch-0.7_chunk-500_C_G_a...      68  2.446
# 4  ../stimuli/combined/switch-0.9_chunk-500_C_G_a...     100  2.178
#
#                               Rating History  ...  Block Duration  \
# 0     [(None, 0.0), (41, 6.48), (41, 7.309)]  ...       18.223059
# 1  [(None, 0.0), (100, 1.817), (100, 2.725)]  ...       31.859845
# 2    [(None, 0.0), (71, 2.784), (71, 3.493)]  ...       46.279105
# 3    [(None, 0.0), (68, 1.726), (68, 2.446)]  ...       59.676363
# 4  [(None, 0.0), (100, 1.333), (100, 2.178)]  ...       72.781313
#
#    Session Duration  Experiment Duration        Start Date  \
# 0       3670.838750            19.814849  2019_Feb_14_1305
# 1       3684.475536            33.451635  2019_Feb_14_1305
# 2       3698.894796            47.870896  2019_Feb_14_1305
# 3       3712.292055            61.268155  2019_Feb_14_1305
# 4       3725.397003            74.373104  2019_Feb_14_1305
#
#                 Experiment Testing Location Experimenter Initials  \
# 0  Sound Switch 12-20-2018       318-laptop                   bpl
# 1  Sound Switch 12-20-2018       318-laptop                   bpl
# 2  Sound Switch 12-20-2018       318-laptop                   bpl
# 3  Sound Switch 12-20-2018       318-laptop                   bpl
# 4  Sound Switch 12-20-2018       318-laptop                   bpl
#
#   Subject Initials Stimulus Type Repeat Trial
# 0              WPH          tone        False
# 1              WPH          tone        False
# 2              WPH          tone        False
# 3              WPH          tone        False
# 4              WPH        guitar        False
#
# [5 rows x 21 columns]

# %% [markdown]
# #### Group results
# Keep only reliable subjects and remove repeated trials.

# %%
main_results = (
    no_repeat_data
    >> group_by("Condition", "Switch Rate", "Stimulus Type")
    >> summarize(mean_ratings=X.Rating.mean(), sd_ratings=X.Rating.std())
)
main_results.head().round(3)
# Out:
#   Stimulus Type  Switch Rate  Condition  mean_ratings  sd_ratings
# 0        guitar          0.1  beautiful        32.832      22.553
# 1          tone          0.1  beautiful        19.111      17.448
# 2        guitar          0.2  beautiful        39.105      20.785
# 3          tone          0.2  beautiful        26.421      18.334
# 4        guitar          0.3  beautiful        42.568      19.312

# %% [markdown]
# ### Plot results

# %%
f, ax = plt.subplots(2, 1, figsize=(8, 12), sharex=True)
sns.despine()
for i, condition in enumerate(main_results["Condition"].unique()):
    these_results = main_results >> mask(X["Condition"] == condition)
    # Convert complexity labels to more informative string labels.
    # Note that seaborn has problems with numbers as categories, 
    # and simple string conversion via `str` doesn't work.    
    sns.lineplot(
        x="Switch Rate",
        y="mean_ratings",
        hue="Stimulus Type",
        data=these_results,
        ax=ax[i],
        linewidth=4
    )
    ax[i].set_title(f"'{condition.title()}' Results")
    ax[i].set(xlabel='Switch Rate', ylabel='Mean Rating')    
plt.show()

# %% [markdown]
# ### Statistical tests

# %% [markdown]
# #### Mixed measures ANOVA.

# %%
# %load_ext rpy2.ipython

# %%
# Convert data to R format
from rpy2.robjects import pandas2ri

R_data = no_repeat_data >> select(
    X["Subject ID"],
    X["Condition"],
    X["Stimulus Type"],
    X["Switch Rate"],
    X["Rating"],
)
R_data = pandas2ri.py2ri(R_data)
R_data.head()
# Out:
# C:\Anaconda3\envs\py36\lib\site-packages\rpy2-2.9.4-py3.6-win-amd64.egg\rpy2\robjects\pandas2ri.py:67: UserWarning: Error while trying to convert the column "Subject ID". Fall back to string conversion. The error is: Conversion 'py2ri' not defined for objects of type '<class 'pandas.core.series.Series'>'
#   (name, str(e)))
# C:\Anaconda3\envs\py36\lib\site-packages\rpy2-2.9.4-py3.6-win-amd64.egg\rpy2\robjects\pandas2ri.py:67: UserWarning: Error while trying to convert the column "Condition". Fall back to string conversion. The error is: Conversion 'py2ri' not defined for objects of type '<class 'pandas.core.series.Series'>'
#   (name, str(e)))
# C:\Anaconda3\envs\py36\lib\site-packages\rpy2-2.9.4-py3.6-win-amd64.egg\rpy2\robjects\pandas2ri.py:67: UserWarning: Error while trying to convert the column "Stimulus Type". Fall back to string conversion. The error is: Conversion 'py2ri' not defined for objects of type '<class 'pandas.core.series.Series'>'
#   (name, str(e)))
# C:\Anaconda3\envs\py36\lib\site-packages\rpy2-2.9.4-py3.6-win-amd64.egg\rpy2\robjects\pandas2ri.py:67: UserWarning: Error while trying to convert the column "Switch Rate". Fall back to string conversion. The error is: Conversion 'py2ri' not defined for objects of type '<class 'pandas.core.series.Series'>'
#   (name, str(e)))
# C:\Anaconda3\envs\py36\lib\site-packages\rpy2-2.9.4-py3.6-win-amd64.egg\rpy2\robjects\pandas2ri.py:67: UserWarning: Error while trying to convert the column "Rating". Fall back to string conversion. The error is: Conversion 'py2ri' not defined for objects of type '<class 'pandas.core.series.Series'>'
#   (name, str(e)))
# R object with classes: ('data.frame',) mapped to:
# <DataFrame - Python:0x0000027FCAB158C8 / R:0x0000027FCDBD7D98>
# [StrVector, StrVector, StrVector, StrVector, StrVector]
#   Subject.ID: <class 'rpy2.robjects.vectors.StrVector'>
#   R object with classes: ('character',) mapped to:
# <StrVector - Python:0x0000027FC46BDA08 / R:0x0000027FCDBD7AC0>
# ['1', '1', '1', '1', '1', '1']
#   Condition: <class 'rpy2.robjects.vectors.StrVector'>
#   R object with classes: ('character',) mapped to:
# <StrVector - Python:0x0000027FCAA9A808 / R:0x0000027FCDBD7A58>
# ['patt..., 'patt..., 'patt..., 'patt..., 'patt..., 'patt...]
#   Stimulus.Type: <class 'rpy2.robjects.vectors.StrVector'>
#   R object with classes: ('character',) mapped to:
# <StrVector - Python:0x0000027FCDB09FC8 / R:0x0000027FCDBD79F0>
# ['tone', 'tone', 'tone', 'tone', 'guit..., 'tone']
#   Switch.Rate: <class 'rpy2.robjects.vectors.StrVector'>
#   R object with classes: ('character',) mapped to:
# <StrVector - Python:0x0000027FCAA9AA08 / R:0x0000027FCDBD7988>
# ['0.3', '0.1', '0.1', '0.7', '0.9', '0.3']
#   Rating: <class 'rpy2.robjects.vectors.StrVector'>
#   R object with classes: ('character',) mapped to:
# <StrVector - Python:0x0000027FCAA9A6C8 / R:0x0000027FCDBD7920>
# ['41', '100', '71', '68', '100', '46']

# %%
# %%R -i R_data -o anova_model,anova_model_summary
# library(afex)
#
# # Convert to numeric, due to pandas converting everything to strings
# R_data <- transform(R_data, Subject.ID = as.numeric(Subject.ID))
# R_data <- transform(R_data, Rating = as.numeric(Rating))
# R_data <- transform(R_data, Switch.Rate = as.numeric(Switch.Rate))
# anova_model <- aov_ez(
#     "Subject.ID",
#     "Rating",
#     R_data,
#     between=c("Condition"),
#     within=c("Switch.Rate", "Stimulus.Type"),
#     type=3 #type of sum squares to use; default is 3
# )
# anova_model_summary = summary(anova_model)
# anova_model_names = names(summary(anova_model))

# %%
print(anova_model)
# Out:
# Anova Table (Type 3 tests)
#
#
#
# Response: Rating
#
#                                Effect           df     MSE         F  ges
#
# 1                           Condition        1, 39 1675.45 47.78 ***  .39
#
# 2                         Switch.Rate 3.18, 124.12  185.71 14.72 ***  .06
#
# 3               Condition:Switch.Rate 3.18, 124.12  185.71 47.32 ***  .18
#
# 4                       Stimulus.Type        1, 39  794.46  11.50 **  .07
#
# 5             Condition:Stimulus.Type        1, 39  794.46   8.26 **  .05
#
# 6           Switch.Rate:Stimulus.Type 6.08, 236.98   35.32      1.61 .003
#
# 7 Condition:Switch.Rate:Stimulus.Type 6.08, 236.98   35.32  4.24 *** .007
#
#   p.value
#
# 1  <.0001
#
# 2  <.0001
#
# 3  <.0001
#
# 4    .002
#
# 5    .007
#
# 6     .15
#
# 7   .0004
#
# ---
#
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '+' 0.1 ' ' 1
#
#
#
# Sphericity correction method: GG

# %% [markdown]
# #### Mixed linear model

# %%
# %%R -i R_data -o linear_model
# library(afex)
# # Convert to numeric, due to pandas converting everything to strings
# R_data <- transform(R_data, Subject.ID = as.numeric(Subject.ID))
# R_data <- transform(R_data, Rating = as.numeric(Rating))
# R_data <- transform(R_data, Switch.Rate = as.numeric(Switch.Rate))
# linear_model <- mixed(Rating~Condition*Switch.Rate*Stimulus.Type+(Switch.Rate|Subject.ID)+(Stimulus.Type|Subject.ID),data=R_data)

# %%
# print(linear_model)

# %% [markdown]
# # Sanity checks

# %% [markdown]
# ## Same number of trials for all subjects?
# All subjects should have exactly 200 trials.

# %%
subject_ids = all_data["Subject ID"].unique()
for subject_id in subject_ids:
    subject_data = all_data >> mask(X["Subject ID"] == subject_id)
    print(subject_data.shape)
# Out:
# (200, 21)
# (200, 21)
# (200, 21)
# (200, 21)
# (200, 21)
# (200, 21)
# (200, 21)
# (200, 21)
# (200, 21)
# (200, 21)
# (200, 21)
# (200, 21)
# (200, 21)
# (200, 21)
# (200, 21)
# (200, 21)
# (200, 21)
# (200, 21)
# (200, 21)
# (200, 21)
# (200, 21)
# (200, 21)
# (200, 21)
# (200, 21)
# (200, 21)
# (200, 21)
# (200, 21)
# (200, 21)
# (200, 21)
# (200, 21)
# (200, 21)
# (200, 21)
# (200, 21)
# (200, 21)
# (200, 21)
# (200, 21)
# (200, 21)
# (200, 21)
# (200, 21)
# (200, 21)
# (200, 21)
# (200, 21)
# (200, 21)
# (200, 21)
# (200, 21)
# (200, 21)
# (200, 21)
# (200, 21)

# %% [markdown]
# ## All stimuli same length?
# Should all be 10,100 ms long.

# %%
test_sanity = False
if test_sanity:
    from pydub import AudioSegment

    stimulus_dir = "../stimuli/combined"
    prefix = "switch-"
    extension = ".mp3"
    search = f"{stimulus_dir}/{prefix}*{extension}"

    song_durations = []
    for song_name in glob.glob(search):
        song = AudioSegment.from_mp3(song_name)
        song_durations.append(len(song))

    print(set(song_durations))

# %% [markdown]
# # Exploration

# %% [markdown]
# ## RT

# %%
sns.set_style("ticks")
sns.distplot(all_data["RT"])
sns.despine()

# %%
no_repeat_data["RT"].describe()
# Out:
# count    7380.000000
# mean        3.207905
# std         4.544249
# min         0.559000
# 25%         1.837000
# 50%         2.462500
# 75%         3.457250
# max       240.151000
# Name: RT, dtype: float64

# %%
no_repeat_data[no_repeat_data["RT"] > 18]
# Out:
#       Subject ID  Condition  Block #  Trial #  Switch Rate  Exemplar  \
# 39             1  patterned        1       40          0.4        10
# 77             1  patterned        1       78          0.7        19
# 82             1  patterned        1       83          0.4         4
# 99             1  patterned        1      100          0.7         0
# 436            3  patterned        1       37          0.1         6
# 465            3  patterned        1       66          0.2        12
# 470            3  patterned        1       71          0.1         7
# 474            3  patterned        1       75          0.4        19
# 1840          10  beautiful        1       41          0.1         6
# 1848          10  beautiful        1       49          0.6        11
# 1853          10  beautiful        1       54          0.1         9
# 1891          10  beautiful        1       92          0.2         7
# 1893          10  beautiful        1       94          0.9         1
# 1896          10  beautiful        1       97          0.8         8
# 1905          10  beautiful        1      106          0.2        14
# 1915          10  beautiful        1      116          0.4        19
# 1916          10  beautiful        1      117          0.8         0
# 1924          10  beautiful        1      125          0.1        12
# 1938          10  beautiful        1      139          0.4        17
# 1946          10  beautiful        1      147          0.2        13
# 1955          10  beautiful        1      156          0.3         8
# 1973          10  beautiful        1      174          0.3        14
# 1978          10  beautiful        1      179          0.1        11
# 2037          11  patterned        1       38          0.1        19
# 2061          11  patterned        1       62          0.8         3
# 4804          25  patterned        1        5          0.8        15
# 4825          25  patterned        1       26          0.2        18
# 4826          25  patterned        1       27          0.8         4
# 4833          25  patterned        1       34          0.9        13
# 4864          25  patterned        1       65          0.6        18
# 5680          29  patterned        1       81          0.8         1
# 5885          30  beautiful        1       86          0.9         0
# 6686          34  beautiful        1       87          0.2        11
# 6690          34  beautiful        1       91          0.2        17
# 6742          34  beautiful        1      143          0.9        11
# 7806          40  beautiful        1        7          0.4        12
# 7810          40  beautiful        1       11          0.9         1
# 7814          40  beautiful        1       15          0.7        10
# 7816          40  beautiful        1       17          0.4         4
# 7855          40  beautiful        1       56          0.6         2
# 8310          42  beautiful        1      111          0.4        17
# 8751          44  beautiful        1      152          0.7        10
# 8753          44  beautiful        1      154          0.5        12
# 8756          44  beautiful        1      157          0.7        12
#
#                                               File Name  Rating       RT  \
# 39    ../stimuli/combined/switch-0.4_chunk-500_C_G_a...      26   31.438
# 77    ../stimuli/combined/switch-0.7_chunk-500_C_G_a...      54   20.168
# 82    ../stimuli/combined/switch-0.4_chunk-500_C_G_a...      49   21.748
# 99    ../stimuli/combined/switch-0.7_chunk-500_C_G_a...      42   35.679
# 436   ../stimuli/combined/switch-0.1_chunk-500_C_G_a...      28   33.481
# 465   ../stimuli/combined/switch-0.2_chunk-500_C_G_a...      50   22.053
# 470   ../stimuli/combined/switch-0.1_chunk-500_C_G_a...      50   22.850
# 474   ../stimuli/combined/switch-0.4_chunk-500_C_G_a...      37   22.819
# 1840  ../stimuli/combined/switch-0.1_chunk-500_C_G_a...      15   19.809
# 1848  ../stimuli/combined/switch-0.6_chunk-500_C_G_a...      16   30.807
# 1853  ../stimuli/combined/switch-0.1_chunk-500_C_G_a...      26   18.993
# 1891  ../stimuli/combined/switch-0.2_chunk-500_C_G_a...      38   31.619
# 1893  ../stimuli/combined/switch-0.9_chunk-500_C_G_a...      22   19.606
# 1896  ../stimuli/combined/switch-0.8_chunk-500_C_G_a...      32   21.637
# 1905  ../stimuli/combined/switch-0.2_chunk-500_C_G_a...      25  137.598
# 1915  ../stimuli/combined/switch-0.4_chunk-500_C_G_a...      20   38.672
# 1916  ../stimuli/combined/switch-0.8_chunk-500_C_G_a...      24  118.849
# 1924  ../stimuli/combined/switch-0.1_chunk-500_C_G_a...      24  240.151
# 1938  ../stimuli/combined/switch-0.4_chunk-500_C_G_a...      25   44.216
# 1946  ../stimuli/combined/switch-0.2_chunk-500_C_G_a...      28   46.088
# 1955  ../stimuli/combined/switch-0.3_chunk-500_C_G_a...      27   25.714
# 1973  ../stimuli/combined/switch-0.3_chunk-500_C_G_a...      36   21.309
# 1978  ../stimuli/combined/switch-0.1_chunk-500_C_G_a...      29   65.141
# 2037  ../stimuli/combined/switch-0.1_chunk-500_C_G_a...      21   71.126
# 2061  ../stimuli/combined/switch-0.8_chunk-500_C_G_a...      69   40.163
# 4804  ../stimuli/combined/switch-0.8_chunk-500_C_G_a...      46   30.305
# 4825  ../stimuli/combined/switch-0.2_chunk-500_C_G_a...      39   22.255
# 4826  ../stimuli/combined/switch-0.8_chunk-500_C_G_a...      61   44.675
# 4833  ../stimuli/combined/switch-0.9_chunk-500_C_G_a...      97   19.038
# 4864  ../stimuli/combined/switch-0.6_chunk-500_C_G_a...      39   30.036
# 5680  ../stimuli/combined/switch-0.8_chunk-500_C_G_a...      23   18.389
# 5885  ../stimuli/combined/switch-0.9_chunk-500_C_G_a...      73   30.929
# 6686  ../stimuli/combined/switch-0.2_chunk-500_C_G_a...      30   19.799
# 6690  ../stimuli/combined/switch-0.2_chunk-500_C_G_a...      18   23.770
# 6742  ../stimuli/combined/switch-0.9_chunk-500_C_G_a...      15   20.705
# 7806  ../stimuli/combined/switch-0.4_chunk-500_C_G_a...      20   23.575
# 7810  ../stimuli/combined/switch-0.9_chunk-500_C_G_a...      37   25.730
# 7814  ../stimuli/combined/switch-0.7_chunk-500_C_G_a...      26   19.663
# 7816  ../stimuli/combined/switch-0.4_chunk-500_C_G_a...      34   25.209
# 7855  ../stimuli/combined/switch-0.6_chunk-500_C_G_a...      30   18.092
# 8310  ../stimuli/combined/switch-0.4_chunk-500_C_G_a...      11   20.279
# 8751  ../stimuli/combined/switch-0.7_chunk-500_C_G_a...      47   18.019
# 8753  ../stimuli/combined/switch-0.5_chunk-500_C_G_a...      53   34.276
# 8756  ../stimuli/combined/switch-0.7_chunk-500_C_G_a...      45   56.617
#
#                                          Rating History  ...  Block Duration  \
# 39            [(None, 0.0), (26, 27.752), (26, 31.438)]  ...      587.330330
# 77             [(None, 0.0), (54, 2.215), (54, 20.168)]  ...     1222.721130
# 82            [(None, 0.0), (49, 21.024), (49, 21.748)]  ...     1332.236674
# 99    [(None, 0.0), (39, 3.208), (38, 3.288), (37, 3...  ...     1655.832170
# 436   [(None, 0.0), (86, 3.12), (84, 5.732), (87, 8....  ...      642.740450
# 465   [(None, 0.0), (51, 17.314), (52, 17.612), (55,...  ...     1196.051392
# 470   [(None, 0.0), (81, 3.069), (82, 4.056), (83, 4...  ...     1288.925168
# 474   [(None, 0.0), (35, 1.684), (37, 1.982), (37, 2...  ...     1367.097471
# 1840            [(None, 0.0), (15, 19.1), (15, 19.809)]  ...      636.515389
# 1848  [(None, 0.0), (7, 4.662), (16, 30.227), (16, 3...  ...      784.436643
# 1853  [(None, 0.0), (15, 4.115), (26, 18.07), (26, 1...  ...      886.686978
# 1891  [(None, 0.0), (29, 1.896), (38, 30.133), (38, ...  ...     1492.245726
# 1893           [(None, 0.0), (22, 2.616), (22, 19.606)]  ...     1536.341065
# 1896           [(None, 0.0), (32, 1.493), (32, 21.637)]  ...     1595.777031
# 1905  [(None, 0.0), (30, 31.609), (25, 33.83), (25, ...  ...     1871.420212
# 1915           [(None, 0.0), (20, 2.944), (20, 38.672)]  ...     2049.566090
# 1916  [(None, 0.0), (15, 3.409), (24, 5.159), (24, 1...  ...     2179.342654
# 1924          [(None, 0.0), (24, 3.116), (24, 240.151)]  ...     2531.859040
# 1938  [(None, 0.0), (24, 13.07), (23, 13.244), (24, ...  ...     2766.226687
# 1946          [(None, 0.0), (28, 38.007), (28, 46.088)]  ...     2932.314989
# 1955          [(None, 0.0), (27, 25.322), (27, 25.714)]  ...     3095.065092
# 1973          [(None, 0.0), (36, 20.588), (36, 21.309)]  ...     3379.128546
# 1978          [(None, 0.0), (29, 64.515), (29, 65.141)]  ...     3512.223814
# 2037          [(None, 0.0), (21, 70.529), (21, 71.126)]  ...      629.862578
# 2061           [(None, 0.0), (69, 1.361), (69, 40.163)]  ...     1003.473858
# 4804           [(None, 0.0), (46, 2.745), (46, 30.305)]  ...       96.122181
# 4825  [(None, 0.0), (57, 20.786), (69, 21.35), (39, ...  ...      410.728430
# 4826          [(None, 0.0), (61, 43.422), (61, 44.675)]  ...      466.319900
# 4833  [(None, 0.0), (95, 6.491), (96, 6.54), (97, 6....  ...      575.954216
# 4864  [(None, 0.0), (52, 26.94), (53, 27.349), (54, ...  ...     1071.643650
# 5680          [(None, 0.0), (23, 17.841), (23, 18.389)]  ...     1132.223402
# 5885          [(None, 0.0), (73, 29.959), (73, 30.929)]  ...     1196.617784
# 6686          [(None, 0.0), (30, 19.412), (30, 19.799)]  ...     1396.302612
# 6690            [(None, 0.0), (18, 18.63), (18, 23.77)]  ...     1473.859065
# 6742          [(None, 0.0), (15, 13.256), (15, 20.705)]  ...     2280.873885
# 7806           [(None, 0.0), (20, 1.135), (20, 23.575)]  ...      138.160822
# 7810  [(None, 0.0), (33, 4.238), (34, 5.508), (37, 6...  ...      229.396563
# 7814  [(None, 0.0), (25, 0.99), (27, 3.614), (26, 4....  ...      307.986939
# 7816  [(None, 0.0), (27, 1.256), (26, 4.35), (29, 5....  ...      369.032577
# 7855  [(None, 0.0), (22, 2.367), (25, 3.603), (26, 7...  ...     1030.586504
# 8310  [(None, 0.0), (10, 2.024), (11, 2.884), (11, 2...  ...     1606.409952
# 8751           [(None, 0.0), (47, 17.42), (47, 18.019)]  ...     2117.653272
# 8753  [(None, 0.0), (53, 33.805), (54, 33.854), (53,...  ...     2182.370619
# 8756           [(None, 0.0), (45, 1.645), (45, 56.617)]  ...     2277.966830
#
#       Session Duration  Experiment Duration        Start Date  \
# 39         4239.946020           588.922120  2019_Feb_14_1305
# 77         4875.336821          1224.312922  2019_Feb_14_1305
# 82         4984.852364          1333.828465  2019_Feb_14_1305
# 99         5308.447862          1657.423963  2019_Feb_14_1305
# 436       15580.991243           661.066573  2019_Feb_15_1159
# 465       16134.302183          1214.377514  2019_Feb_15_1159
# 470       16227.175960          1307.251290  2019_Feb_15_1159
# 474       16305.348263          1385.423595  2019_Feb_15_1159
# 1840       1793.297770           653.057172  2019_Feb_19_1118
# 1848       1941.219025           800.978426  2019_Feb_19_1118
# 1853       2043.469360           903.228762  2019_Feb_19_1118
# 1891       2649.028109          1508.787511  2019_Feb_19_1118
# 1893       2693.123446          1552.882848  2019_Feb_19_1118
# 1896       2752.559412          1612.318814  2019_Feb_19_1118
# 1905       3028.202593          1887.961996  2019_Feb_19_1118
# 1915       3206.348471          2066.107873  2019_Feb_19_1118
# 1916       3336.125037          2195.884439  2019_Feb_19_1118
# 1924       3688.641422          2548.400824  2019_Feb_19_1118
# 1938       3923.009068          2782.768471  2019_Feb_19_1118
# 1946       4089.097370          2948.856772  2019_Feb_19_1118
# 1955       4251.847474          3111.606876  2019_Feb_19_1118
# 1973       4535.910927          3395.670329  2019_Feb_19_1118
# 1978       4669.006195          3528.765598  2019_Feb_19_1118
# 2037        874.398125           643.638551  2019_Feb_19_1356
# 2061       1248.009405          1017.249828  2019_Feb_19_1356
# 4804       3276.009504           114.307049  2019_Feb_25_1504
# 4825       3590.615754           428.913299  2019_Feb_25_1504
# 4826       3646.207223           484.504769  2019_Feb_25_1504
# 4833       3755.841539           594.139083  2019_Feb_25_1504
# 4864       4251.530973          1089.828518  2019_Feb_25_1504
# 5680       2365.210864          1148.334205  2019_Feb_27_0902
# 5885       3512.736989          1212.031314  2019_Feb_27_1018
# 6686       1632.841502          1422.696275  2019_Feb_28_1411
# 6690       1710.397955          1500.252728  2019_Feb_28_1411
# 6742       2517.412775          2307.267548  2019_Feb_28_1411
# 7806       2328.680581           174.286833  2019_Mar_05_1004
# 7810       2419.916322           265.522575  2019_Mar_05_1004
# 7814       2498.506698           344.112950  2019_Mar_05_1004
# 7816       2559.552336           405.158589  2019_Mar_05_1004
# 7855       3221.106263          1066.712515  2019_Mar_05_1004
# 8310       4041.692514          1622.384782  2019_Mar_06_0836
# 8751       3621.313122          2135.355499  2019_Mar_07_0901
# 8753       3686.030470          2200.072847  2019_Mar_07_0901
# 8756       3781.626680          2295.669058  2019_Mar_07_0901
#
#                    Experiment Testing Location Experimenter Initials  \
# 39    Sound Switch 12-20-2018       318-laptop                   bpl
# 77    Sound Switch 12-20-2018       318-laptop                   bpl
# 82    Sound Switch 12-20-2018       318-laptop                   bpl
# 99    Sound Switch 12-20-2018       318-laptop                   bpl
# 436   Sound Switch 12-20-2018       318-laptop                   bpl
# 465   Sound Switch 12-20-2018       318-laptop                   bpl
# 470   Sound Switch 12-20-2018       318-laptop                   bpl
# 474   Sound Switch 12-20-2018       318-laptop                   bpl
# 1840  Sound Switch 12-20-2018       318-laptop                   bpl
# 1848  Sound Switch 12-20-2018       318-laptop                   bpl
# 1853  Sound Switch 12-20-2018       318-laptop                   bpl
# 1891  Sound Switch 12-20-2018       318-laptop                   bpl
# 1893  Sound Switch 12-20-2018       318-laptop                   bpl
# 1896  Sound Switch 12-20-2018       318-laptop                   bpl
# 1905  Sound Switch 12-20-2018       318-laptop                   bpl
# 1915  Sound Switch 12-20-2018       318-laptop                   bpl
# 1916  Sound Switch 12-20-2018       318-laptop                   bpl
# 1924  Sound Switch 12-20-2018       318-laptop                   bpl
# 1938  Sound Switch 12-20-2018       318-laptop                   bpl
# 1946  Sound Switch 12-20-2018       318-laptop                   bpl
# 1955  Sound Switch 12-20-2018       318-laptop                   bpl
# 1973  Sound Switch 12-20-2018       318-laptop                   bpl
# 1978  Sound Switch 12-20-2018       318-laptop                   bpl
# 2037  Sound Switch 12-20-2018       318-laptop                   bpl
# 2061  Sound Switch 12-20-2018       318-laptop                   bpl
# 4804  Sound Switch 12-20-2018       318-laptop                   bpl
# 4825  Sound Switch 12-20-2018       318-laptop                   bpl
# 4826  Sound Switch 12-20-2018       318-laptop                   bpl
# 4833  Sound Switch 12-20-2018       318-laptop                   bpl
# 4864  Sound Switch 12-20-2018       318-laptop                   bpl
# 5680  Sound Switch 12-20-2018       318-laptop                   bpl
# 5885  Sound Switch 12-20-2018       318-laptop                   bpl
# 6686  Sound Switch 12-20-2018       318-laptop                   bpl
# 6690  Sound Switch 12-20-2018       318-laptop                   bpl
# 6742  Sound Switch 12-20-2018       318-laptop                   bpl
# 7806  Sound Switch 12-20-2018       318-laptop                   bpl
# 7810  Sound Switch 12-20-2018       318-laptop                   bpl
# 7814  Sound Switch 12-20-2018       318-laptop                   bpl
# 7816  Sound Switch 12-20-2018       318-laptop                   bpl
# 7855  Sound Switch 12-20-2018       318-laptop                   bpl
# 8310  Sound Switch 12-20-2018       318-laptop                   bpl
# 8751  Sound Switch 12-20-2018       318-laptop                   bpl
# 8753  Sound Switch 12-20-2018       318-laptop                   bpl
# 8756  Sound Switch 12-20-2018       318-laptop                   bpl
#
#      Subject Initials Stimulus Type Repeat Trial
# 39                WPH          tone        False
# 77                WPH          tone        False
# 82                WPH        guitar        False
# 99                WPH        guitar        False
# 436                ST        guitar        False
# 465                ST          tone        False
# 470                ST        guitar        False
# 474                ST          tone        False
# 1840               SB        guitar        False
# 1848               SB          tone        False
# 1853               SB        guitar        False
# 1891               SB        guitar        False
# 1893               SB        guitar        False
# 1896               SB        guitar        False
# 1905               SB          tone        False
# 1915               SB          tone        False
# 1916               SB        guitar        False
# 1924               SB          tone        False
# 1938               SB          tone        False
# 1946               SB          tone        False
# 1955               SB        guitar        False
# 1973               SB          tone        False
# 1978               SB          tone        False
# 2037               TZ          tone        False
# 2061               TZ        guitar        False
# 4804               JR          tone        False
# 4825               JR          tone        False
# 4826               JR        guitar        False
# 4833               JR          tone        False
# 4864               JR          tone        False
# 5680              CZY        guitar        False
# 5885               TW        guitar        False
# 6686              MTA          tone        False
# 6690              MTA          tone        False
# 6742              MTA          tone        False
# 7806               SN          tone        False
# 7810               SN        guitar        False
# 7814               SN          tone        False
# 7816               SN        guitar        False
# 7855               SN        guitar        False
# 8310              FGM          tone        False
# 8751               TA          tone        False
# 8753               TA          tone        False
# 8756               TA          tone        False
#
# [44 rows x 21 columns]

# %%
sns.distplot(no_repeat_data["RT"])
sns.despine()

# %% [markdown]
# # Scrap

# %%
# Remove subjects with "None" rating data
# all_data = all_data.replace(to_replace="None", value=np.nan).dropna()

# %%
# subject_reliability_df = pd.DataFrame(
#     index=[],
#     columns=[
#         "subject_id",
#         "condition",        
#         "correlation",
#         "p-value",
#         "fisher_z",
#     ],
# )
# subject_ids = all_data["Subject ID"].unique()
# for subject_id in subject_ids:
#     subject_data = all_data >> mask(X["Subject ID"] == subject_id)
#     subject_data.sort_values(by=["File Name"], inplace=True)
#     repeated_stimuli = (
#         subject_data 
#         >> mask(X["Repeat Trial"] == True)
#         >> select(["File Name"])
#     )
    
#     first_ratings_data = subject_data[
#         (subject_data["File Name"].isin(repeated_stimuli["File Name"]))
#         & (subject_data["Repeat Trial"] == False)
#     ]["Rating"].tolist()
    
#     second_ratings_data = subject_data[
#         (subject_data["File Name"].isin(repeated_stimuli["File Name"]))
#         & (subject_data["Repeat Trial"] == True)
#     ]["Rating"].tolist()
    
#     # Correct for subjects where one or more repeat trials had to be discarded
#     if len(first_ratings_data) != len(second_ratings_data):
#         first_ratings_stimuli = subject_data[
#             (subject_data["File Name"].isin(repeated_stimuli["File Name"]))
#             & (subject_data["Repeat Trial"] == False)
#         ]["File Name"].tolist()
        
#         second_ratings_stimuli = subject_data[
#             (subject_data["File Name"].isin(repeated_stimuli["File Name"]))
#             & (subject_data["Repeat Trial"] == True)
#         ]["File Name"].tolist()
                
#         if len(first_ratings_stimuli) < len(second_ratings_stimuli):
#             smaller_set = set(first_ratings_stimuli)
#             larger_set = set(second_ratings_stimuli)
#         else:
#             smaller_set = set(second_ratings_stimuli)
#             larger_set = set(first_ratings_stimuli)
                    
#         missing_stimuli = larger_set.difference(smaller_set)
#         pass
    
#     subject_reliability_corr = scipy.stats.pearsonr(
#         first_ratings_data, second_ratings_data
#     )
    
#     # Needs to be in arrays for pandas
#     # XXX break down by stimulus type?
#     this_corr_row = {
#         "subject_id": [subject_id],
#         "condition": [subject_data["Condition"].iloc[0]],        
#         "correlation": [subject_reliability_corr[0]],
#         "p-value": [subject_reliability_corr[1]],
#         "fisher_z": [np.arctanh(subject_reliability_corr[0])],
#     }
#     this_corr_row = pd.DataFrame.from_dict(this_corr_row)
#     subject_reliability_df = subject_reliability_df.append(this_corr_row)
    
# subject_reliability_df
